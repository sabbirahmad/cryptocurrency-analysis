# %%
import pandas as pd
import numpy as np

# %%
fileLoc = './all-crypto-currencies/crypto-markets.csv'
data = pd.read_csv(fileLoc, names=['slug', 'symbol', 'name', 'date', 'ranknow', 'open', 'high', 'low', 'close', 'volume', 'market', 'close_ratio', 'spread'], header=None)
data.dropna()
# Out:
# C:\Users\raghu\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (4,5,6,7,8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            slug  symbol     name        date  ranknow      open      high  \
# 0          slug  symbol     name        date  ranknow      open      high
# 1       bitcoin     BTC  Bitcoin  2013-04-28        1     135.3    135.98
# 2       bitcoin     BTC  Bitcoin  2013-04-29        1    134.44    147.49
# 3       bitcoin     BTC  Bitcoin  2013-04-30        1       144    146.93
# 4       bitcoin     BTC  Bitcoin  2013-05-01        1       139    139.89
# 5       bitcoin     BTC  Bitcoin  2013-05-02        1    116.38     125.6
# 6       bitcoin     BTC  Bitcoin  2013-05-03        1    106.25    108.13
# 7       bitcoin     BTC  Bitcoin  2013-05-04        1      98.1       115
# ...

# %%
data[:10]
# Out:
#       slug  symbol     name        date  ranknow    open    high     low  \
# 0     slug  symbol     name        date  ranknow    open    high     low
# 1  bitcoin     BTC  Bitcoin  2013-04-28        1   135.3  135.98   132.1
# 2  bitcoin     BTC  Bitcoin  2013-04-29        1  134.44  147.49     134
# 3  bitcoin     BTC  Bitcoin  2013-04-30        1     144  146.93  134.05
# 4  bitcoin     BTC  Bitcoin  2013-05-01        1     139  139.89  107.72
# 5  bitcoin     BTC  Bitcoin  2013-05-02        1  116.38   125.6   92.28
# 6  bitcoin     BTC  Bitcoin  2013-05-03        1  106.25  108.13    79.1
# 7  bitcoin     BTC  Bitcoin  2013-05-04        1    98.1     115    92.5
# 8  bitcoin     BTC  Bitcoin  2013-05-05        1   112.9   118.8  107.14
# 9  bitcoin     BTC  Bitcoin  2013-05-06        1  115.98  124.66  106.64
#
#     close  volume      market  close_ratio  spread
# 0   close  volume      market  close_ratio  spread
# 1  134.21       0  1500520000       0.5438    3.88
# ...

# %%
values = data['slug'].value_counts().keys().tolist()[:10]
counts = data['slug'].value_counts().tolist()
values.insert(len(values), 'Others')

# %%
limt_count = counts[:10]
limt_count.insert(len(limt_count), sum(counts[10:50]))

# %%
values
# Out:
# ['bitcoin',
#  'litecoin',
#  'namecoin',
#  'novacoin',
#  'peercoin',
#  'feathercoin',
#  'terracoin',
#  'bitbar',
#  'worldcoin',
#  'digitalcoin',
#  'Others']

# %%
import matplotlib.pyplot as plt

# Data to plot
#labels = 'Python', 'C++', 'Ruby', 'Java'
#sizes = [215, 130, 245, 210]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
#explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(limt_count, labels=values,
        autopct='%1.1f%%', radius=5 ,shadow=True, startangle=140)
plt.rc('font', size=30) 
plt.show()

# %%
#2013-07-29
data.loc[data['date'] == '2018-02-21']
# Out:
#                         slug symbol                  name        date ranknow  \
# 1761                 bitcoin    BTC               Bitcoin  2018-02-21       1
# 2691                ethereum    ETH              Ethereum  2018-02-21       2
# 4354                  ripple    XRP                Ripple  2018-02-21       3
# 4568            bitcoin-cash    BCH          Bitcoin Cash  2018-02-21       4
# 6329                litecoin    LTC              Litecoin  2018-02-21       5
# 6473                 cardano    ADA               Cardano  2018-02-21       6
# 7004                     neo    NEO                   NEO  2018-02-21       7
# 8301                 stellar    XLM               Stellar  2018-02-21       8
# 8537                     eos    EOS                   EOS  2018-02-21       9
# 10006                   dash   DASH                  Dash  2018-02-21      10
# 11378                 monero    XMR                Monero  2018-02-21      11
# ...

# %%
date_data = data.loc[data['date'] == '2018-02-21']

# %%
date_data['market'].astype(np.int64)
# Out:
# 1761      191927000000
# 2691       87394200000
# 4354       42207600000
# 4568       23988100000
# 6329       12773200000
# 6473        9738030000
# 7004        8298400000
# 8301        7381920000
# 8537        6315770000
# 10006       5435710000
# 11378       4761040000
# 11632       5270980000
# 12690       4339330000
# 13268       3807360000
# 13430       3084190000
# 13614       2955150000
# 14301       2658780000
# 15389       2229030000
# 15511       2224630000
# 15785       2281560000
# 16008       1869530000
# 16126       1615600000
# 16607       1458040000
# 16944        927731000
# 18160       1022620000
# 18835       1033440000
# 20181       1015580000
# 20393        978027000
# 20618        916478000
# 21528        801953000
#               ...
# 685116               0
# 685851               0
# 686432               0
# 687021               0
# 687328               0
# 687609               0
# 688105               0
# 688270               0
# 689114               0
# ...

# %%
marketcap = [191927000000, 87394200000, 42207600000, 23988100000, 12773200000, 9738030000, 8298400000, 7381920000, 6315770000, 5435710000]
width = 1/1.5

# %%
N = len(marketcap)
x = range(N)

plt.bar(x, marketcap, width, color="blue")
plt.xticklabels(('Bitcoin', 'Ethereum', 'Ripple', 'Bitcoin Cash', 'Litecoin', 'Cardano', 'NEO', 'Stellar', 'EOS', 'Dash'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-247-5943f010282f> in <module>()
#       3
#       4 plt.bar(x, marketcap, width, color="blue")
# ----> 5 plt.xticklabels(('Bitcoin', 'Ethereum', 'Ripple', 'Bitcoin Cash', 'Litecoin', 'Cardano', 'NEO', 'Stellar', 'EOS', 'Dash'))
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xticklabels'

# %%
market_cap = [191927000000, 87394200000, 42207600000, 23988100000, 12773200000, 9738030000, 8298400000, 7381920000, 6315770000, 5435710000]

ind = np.arange(len(market_cap))  # the x locations for the groups
width = 0.35  # the width of the bars
plt.rc('font', size=15) 
fig, ax = plt.subplots(figsize=(18,18))
rects = ax.bar(ind - width/2, market_cap, width, label='Men')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Market cap')
ax.set_title('Market cap plot for top 10 crypto currencies')
ax.set_xticks(ind)
ax.set_xticklabels(('Bitcoin', 'Ethereum', 'Ripple', 'Bitcoin Cash', 'Litecoin', 'Cardano', 'NEO', 'Stellar', 'EOS', 'Dash'))
# Out:
# [Text(0,0,'Bitcoin'),
#  Text(0,0,'Ethereum'),
#  Text(0,0,'Ripple'),
#  Text(0,0,'Bitcoin Cash'),
#  Text(0,0,'Litecoin'),
#  Text(0,0,'Cardano'),
#  Text(0,0,'NEO'),
#  Text(0,0,'Stellar'),
#  Text(0,0,'EOS'),
#  Text(0,0,'Dash')]

# %%
date_data = data.loc[data['date'] == '2018-02-21']
